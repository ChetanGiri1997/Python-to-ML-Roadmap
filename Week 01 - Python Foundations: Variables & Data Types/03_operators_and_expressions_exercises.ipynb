# %% [markdown]
# 1.Use arithmetic operators to compute (5 + 3) * 2.

# %% [markdown]
# 2.Compute 10 / 2 and note the type.

# %% [markdown]
# 3.Use // for 10 / 3.

# %% [markdown]
# 4.Compute 7 % 4.

# %% [markdown]
# 5.Compute 7 % 4.

# %% [markdown]
# 6.Use += to increment a variable by 5.

# %% [markdown]
# 7.Use -= on a variable.

# %% [markdown]
# 8.Compare two numbers with >, <, >=, <=.

# %% [markdown]
# 9.Check equality of two strings.

# %% [markdown]
# 10.Use != on two booleans.

# %% [markdown]
# 11.Use and, or on booleans.

# %% [markdown]
# 12.Use not on a comparison.

# %% [markdown]
# 13.Chain comparisons like 1 < 2 < 3.

# %% [markdown]
# 14.Use is operator on two identical integers.

# %% [markdown]
# 15.Use is not on None.

# %% [markdown]
# 16.Bitwise AND on 5 & 3.

# %% [markdown]
# 17.Bitwise OR on 5 | 3.

# %% [markdown]
# 18.Bitwise XOR on 5 ^ 3.

# %% [markdown]
# 19.Left shift 5 << 1.

# %% [markdown]
# 20.Right shift 5 >> 1.

# %% [markdown]
# 21.Invert bits of 5 using ~.

# %% [markdown]
# 22.Combine arithmetic and assignment like *=.

# %% [markdown]
# 23.Use operator precedence in (5 + 3) * 2 vs 5 + 3 * 2.

# %% [markdown]
# 24.Compare float and int equality.

# %% [markdown]
# 25.Use in operator on string for substring check.
