# %% [markdown]
# 1.Implement an advanced if-elif chain to assign grades (A, B, C, …) based on marks.

# %% [markdown]
# 2.Use a ternary operator to find the maximum of two numbers.

# %% [markdown]
# 3.Write a list comprehension to filter out even numbers.

# %% [markdown]
# 4.Use nested comprehensions to generate a 2D list (matrix).

# %% [markdown]
# 5.Include an if condition inside a comprehension (e.g., keep only positive numbers).

# %% [markdown]
# 6.Use a while loop with a complex condition (e.g., stop when both x > 5 and y < 20).

# %% [markdown]
# 7.Write a loop to handle lists of lists (nested iteration).

# %% [markdown]
# 8.Simulate a queue using a list and loops (enqueue/dequeue operations).

# %% [markdown]
# 9.Simulate a stack using a list and loops (push/pop operations).

# %% [markdown]
# 10.Use a loop to compute the transpose of a matrix.

# %% [markdown]
# 11.Find common elements between two lists using loops.

# %% [markdown]
# 12.Check if two strings are anagrams using loops.

# %% [markdown]
# 13.Write a program to check if a sentence is a pangram (contains all alphabets).

# %% [markdown]
# 14.Implement a simple Caesar cipher using loops.

# %% [markdown]
# 15.Generate all permutations of a small string using loops (no recursion).

# %% [markdown]
# 16.Write a loop to calculate basic statistics (mean of a list).

# %% [markdown]
# 17.Calculate variance of a list manually using loops.

# %% [markdown]
# 18.Implement Bubble Sort using loops.

# %% [markdown]
# 19.Implement Selection Sort using loops.

# %% [markdown]
# 20.Implement Insertion Sort using loops.

# %% [markdown]
# 21.Implement Linear Search using a loop.

# %% [markdown]
# 22.Implement Binary Search manually using loops.

# %% [markdown]
# 23.Use loops to handle errors simply (e.g., ask for input until a valid integer is entered).

# %% [markdown]
# 24.Print complex patterns (triangles, pyramids, diamonds) using loops.

# %% [markdown]
# 25.Simulate recursion using loops (e.g., factorial without recursion).
