# %% [markdown]
# 1. Create a variable named name and assign your full name as a string to it.

# %%
name = "Your Name"

# %% [markdown]
# 2. Print the value of name.

# %%
print(name)
# Out:
# Your Name

# %% [markdown]
# 3. Create an integer variable age with your age.

# %%
age = 27

# %% [markdown]
# 4.Print the type of age using type().

# %%
print(age)
# Out:
# 27

# %% [markdown]
# 5.Create a float variable height with your height in meters.

# %%
height = 5.7

# %% [markdown]
# 6.Convert height to an integer and print it.

# %%
print(height)
print(int(height))
# Out:
# 5.7
# 5

# %% [markdown]
# 7.Create a boolean variable is_student set to True if you are a student.

# %%
is_student = True

# %% [markdown]
# 8.Print is_student and its type.

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %% [markdown]
# 9.Create a string variable city with your city name.

# %%
city = "surkhet"

# %% [markdown]
# 10.Concatenate name and city with a space and print.

# %%
print(name + city)
# Out:
# Your Namesurkhet

# %% [markdown]
# 11.Use string formatting to print "My name is {name} and I am {age} years old."

# %%
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Your Name and I am 27 years old

# %% [markdown]
# 12.Create a complex number variable comp with real part 3 and imaginary part 4.

# %%
comp = complex(3, 4)
# or
comp = 3 + 4j

# %% [markdown]
# 13.Print the real and imaginary parts of comp.

# %%
print("Real part:", comp.real)
print("Imaginary part:", comp.imag)
# Out:
# Real part: 3.0
# Imaginary part: 4.0

# %% [markdown]
# 14.Assign None to a variable empty and check its type.

# %%
empty = None
print(type(empty))
# Out:
# <class 'NoneType'>

# %% [markdown]
# 15.Create two string variables and compare them using ==.

# %%
s1 = "apple"
s2 = "apple"
print(s1 == s2)
# Out:
# True

# %% [markdown]
# 16.Create an integer and a float, add them, and print the result.

# %%
i = 7
f = 2.5
print(i + f)
# Out:
# 9.5

# %% [markdown]
# 17.Use the + operator on two strings.

# %%
print("Hello, " + "world!")
# Out:
# Hello, world!

# %% [markdown]
# 18.Multiply a string by an integer (e.g., "hello" * 3).

# %%
print("hello" * 3)
# Out:
# hellohellohello

# %% [markdown]
# 19.Divide two integers and note the result type.

# %%
print(7 / 2)
# Out:
# 3.5

# %% [markdown]
# 20.Use floor division on two floats.

# %%
print(7.5 // 2.2)
# Out:
# 3.0

# %% [markdown]
# 21.Calculate the modulus of 10 % 3.

# %%
print(10 % 3)
# Out:
# 1

# %% [markdown]
# 22.Raise 2 to the power of 5 using **.

# %%
print(2 ** 5)
# Out:
# 32

# %% [markdown]
# 23.Check if 5 > 3 and print the boolean result.

# %%
print(5 > 3)
# Out:
# True

# %% [markdown]
# 24.Use logical AND on two true booleans.

# %%
print(True and True)
# Out:
# True

# %% [markdown]
# 25.Use logical NOT on a false boolean.

# %%
value = False
print(not value)
# Out:
# True
