# %% [markdown]
# 1.Write an if statement to check if a number is positive.

# %% [markdown]
# 2.Add else to print if negative or zero.

# %% [markdown]
# 3.Use elif to check if zero separately.

# %% [markdown]
# 4.Nest if statements to check even/odd and positive.

# %% [markdown]
# 5.Use if to check if a string is empty.

# %% [markdown]
# 6.Write a for loop to print numbers 1 to 10.

# %% [markdown]
# 7.Loop over a list and print each element.

# %% [markdown]
# 8.Use range() in a for loop.

# %% [markdown]
# 9.Break a loop when condition met.

# %% [markdown]
# 10.Continue to skip even numbers in loop.

# %% [markdown]
# 11.Use else with for loop.

# %% [markdown]
# 12.Write a while loop to count down from 10.

# %% [markdown]
# 13.Infinite while with break.

# %% [markdown]
# 14.Use pass in an empty loop.

# %% [markdown]
# 15.Use pass in an empty loop.

# %% [markdown]
# 16.Zip two lists in a loop.

# %% [markdown]
# 17.Reverse a loop using range.

# %% [markdown]
# 18.Nested loops for multiplication table.

# %% [markdown]
# 19.Use if in a loop to filter odds.

# %% [markdown]
# 20.Accumulate sum in a loop.

# %% [markdown]
# 21.Find max in a list using loop.

# %% [markdown]
# 22.Check palindrome using loop.

# %% [markdown]
# 23.Generate Fibonacci with loop.

# %% [markdown]
# 24.Loop to count characters in string.

# %% [markdown]
# 25.Use loop to create a list of evens.
