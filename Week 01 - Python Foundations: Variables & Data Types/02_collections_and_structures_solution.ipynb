# %% [markdown]
# 1.Create a list with 5 integers.

# %%
ll = [1,2,3,4,5]

# %% [markdown]
# 2.Print the length of the list.

# %%
print(len(ll))
# Out:
# 5

# %% [markdown]
# 3.Access the first and last elements of the list.

# %%
print(ll[0], ll[-1])
# Out:
# 1 5

# %% [markdown]
# 4.Slice the list to get elements from index 1 to 3.

# %%
print(ll[1:4])
# Out:
# [2, 3, 4]

# %% [markdown]
# 5.Append a new element to the list.

# %%
ll.append(6)
print(ll)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 6.Insert an element at index 2.

# %%
ll.insert(2, 99)
print(ll)
# Out:
# [1, 2, 99, 3, 4, 5, 6]

# %% [markdown]
# 7.Remove the last element using pop().

# %%
ll.pop()
print(ll)
# Out:
# [1, 2, 99, 3, 4, 5]

# %% [markdown]
# 8.Check if a specific element is in the list using 'in'.

# %%
print(3 in ll)
# Out:
# True

# %% [markdown]
# 9.Create a tuple with 3 strings.

# %%
t = ("red", "green", "blue")
print(t)
# Out:
# ('red', 'green', 'blue')

# %% [markdown]
# 10.Try to modify the tuple and observe the error.

# %%
t[0] = "yellow"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t[0] = "yellow"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 11.Unpack the tuple into variables.

# %%
a, b, c = t
print(a, b, c)
# Out:
# red green blue

# %% [markdown]
# 12.Create a set with duplicate numbers and print it.

# %%
s = {1, 2, 2, 3, 4, 4}
print(s)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 13.Add an element to the set.

# %%
s.add(5)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 14.Remove an element from the set.

# %%
s.remove(3)
print(s)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# 15.Check intersection of two sets.

# %%
s2 = {3, 4, 5, 6}
print(s.intersection(s2))
# Out:
# {4, 5}

# %% [markdown]
# 16.Create a dictionary with keys 'name', 'age' and values.

# %%
d = {"name": "Ram", "age": 25}
print(d)
# Out:
# {'name': 'Ram', 'age': 25}

# %% [markdown]
# 17.Access a value by key.

# %%
print(d["name"])
# Out:
# Ram

# %% [markdown]
# 18.Add a new key-value pair.

# %%
d["city"] = "Surkhet"
print(d)
# Out:
# {'name': 'Ram', 'age': 25, 'city': 'Surkhet'}

# %% [markdown]
# 19.Remove a key using del.

# %%
del d["age"]
print(d)
# Out:
# {'name': 'Ram', 'city': 'Surkhet'}

# %% [markdown]
# 20.Get all keys and values.

# %%
print(d.keys())
print(d.values())
# Out:
# dict_keys(['name', 'city'])
# dict_values(['Ram', 'Surkhet'])

# %% [markdown]
# 21.Check if a key exists in the dictionary.

# %%
print("name" in d)
# Out:
# True

# %% [markdown]
# 22.Check if a key exists in the dictionary.

# %%
print("age" in d)
# Out:
# False

# %% [markdown]
# 23.Use list comprehension to create a list of squares from 1 to 10.

# %%
squares = [x*x for x in range(1, 11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# 24.Convert a list to a set.

# %%
nums = [1, 2, 2, 3, 4]
print(set(nums))
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 24.Merge two dictionaries.

# %%
d1 = {"a": 1, "b": 2}
d2 = {"b": 3, "c": 4}
merged = {**d1, **d2}
print(merged)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# 25.Sort a list of numbers.

# %%
lst = [5, 1, 4, 2, 3]
lst.sort()
print(lst)
# Out:
# [1, 2, 3, 4, 5]
