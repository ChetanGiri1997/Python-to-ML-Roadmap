# %% [markdown]
# 1.Write an if statement to check multiple conditions using and (e.g., check if a number is between 10 and 50).

# %% [markdown]
# 2.Use or in an if statement (e.g., check if a character is a vowel or special symbol).

# %% [markdown]
# 3.Write a nested if to determine the quadrant of a point (x, y).

# %% [markdown]
# 4.Write an if statement to check if a year is a leap year.

# %% [markdown]
# 5.Use a loop to calculate the sum of numbers from 1 to 100.

# %% [markdown]
# 6.Use a loop to calculate the product of all elements in a list.

# %% [markdown]
# 7.Find the minimum and maximum values in a list using loops.

# %% [markdown]
# 8.Reverse a list manually using a loop (no .reverse() or slicing).

# %% [markdown]
# 9.Remove duplicates from a list using loops.

# %% [markdown]
# 10.Count occurrences of each element in a list using a loop.

# %% [markdown]
# 11.Use a for loop to iterate through a string and print its characters.

# %% [markdown]
# 12.Generate a Fibonacci sequence using a while loop.

# %% [markdown]
# 13.Calculate factorial of a number using a loop.

# %% [markdown]
# 14.Print all prime numbers up to n.
